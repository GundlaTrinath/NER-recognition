# %%
# !pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.0.6-cp38-cp38-win_amd64.whl (11.9 MB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\thrived\anaconda3\lib\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: setuptools in c:\users\thrived\anaconda3\lib\site-packages (from spacy) (52.0.0.post20210125)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.0-py3-none-any.whl (42 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.4
#   Downloading spacy_legacy-3.0.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\thrived\anaconda3\lib\site-packages (from spacy) (1.20.1)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-win_amd64.whl (112 kB)
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading pydantic-1.7.4-cp38-cp38-win_amd64.whl (1.8 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\thrived\anaconda3\lib\site-packages (from spacy) (20.9)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.1-cp38-cp38-win_amd64.whl (451 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-win_amd64.whl (6.5 MB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Using cached wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting catalogue<2.1.0,>=2.0.3
#   Downloading catalogue-2.0.4-py3-none-any.whl (16 kB)
# Collecting thinc<8.1.0,>=8.0.3
#   Downloading thinc-8.0.7-cp38-cp38-win_amd64.whl (1.0 MB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-win_amd64.whl (21 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\thrived\anaconda3\lib\site-packages (from spacy) (4.59.0)
# Requirement already satisfied: jinja2 in c:\users\thrived\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-win_amd64.whl (36 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\thrived\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting smart-open<6.0.0,>=5.0.0
#   Using cached smart_open-5.1.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thrived\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\thrived\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\thrived\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thrived\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\thrived\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\thrived\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, thinc, spacy-legacy, pathy, spacy
# Successfully installed blis-0.7.4 catalogue-2.0.4 cymem-2.0.5 murmurhash-1.0.5 pathy-0.6.0 preshed-3.0.5 pydantic-1.7.4 smart-open-5.1.0 spacy-3.0.6 spacy-legacy-3.0.6 srsly-2.4.1 thinc-8.0.7 typer-0.3.2 wasabi-0.8.2

# %%
import moviepy.editor
import tkinter.filedialog
from pydub import AudioSegment
import os
import speech_recognition as sp
import spacy
import spacy.displacy as displacy

# %%
from pydub.silence import split_on_silence
import os

# %%
#Video and audio proccessi ng and conversion to textual data with ".txt" file 
videoSrc = "Video.mp4"
audio_store = 'Extracted_audio.wav'
video = moviepy.editor.VideoFileClip(videoSrc)
audio = video.audio
audio.write_audiofile(audio_store)
# Out:
# chunk:   0%|                                                                       | 0/11858 [00:00<?, ?it/s, now=None]
# MoviePy - Writing audio in Extracted_audio.wav
# MoviePy - Done.

# %%
speech  = sp.Recognizer()

# %%
with sp.AudioFile('Extracted_audio.wav') as source:
    audio = speech.listen(source)
    try:
        text = speech.recognize_google(audio)
        print(text)
    except:
        print('invalid!')
# Out:
# Janu China building a gateway to South Asia new Metropolis about the same size in Central London financial analyst in Dubai with business friendly atmosphere like Singapore which city will be lined with chinese skyscrapers exotic hotels in theme park IL have a population of about 80,000 people with thousands more commuting each day that a new job opportunities good money and a good Lifestyle I know it sounds like an enticing plan but wait till you here where this plan is being hacked right in the backyard of India just 290 km away from Tamilnadu this is port city Colombo you know how it been built by reclaiming several hectares of land from the see you know why it being built to give China strategic age in the Indian Ocean as I speak 10 the Sri Lankan ship sponsored by China a working overtime to read stand from the bottom of the Indian Ocean and put it on a 600 acres trip to get the city going the question is shouldn't get going at all hello and welcome to gravitaz plus sample Sharma Upadhyay China's building and other nest in Sri Lanka Colombo port city of 1.4 billion dollar project overlooking the Colombo port which city is part of China built and Road initiative the same initiative which is plant several countries into debt and that is just one piece of the puzzle here the concerns are many will get there in a bit first let's understand what this project really is the idea came from Mahinda Rajapaksa when he was the president of Sri Lanka he was inspecting a landfill near Columbus South port and said to have been inspired to build a well planned City based on a model of the world biggest financial hub there was 2004 for the next 10 years several proposals were made with the idea never saw the light of day then in 2014 China and the picture with checkbox and construction mind to state on Chinese companies M Din unsolicited proposal to fulfill M Rajapaksa dream Sri Lanka accept the proposal why wouldn't it be Chinese firms were among fortune 500 companies it from it all in one packages reclaiming land from the Sea constructing breakwater connecting Road network the supply of services the work but what we say it's them

# %%
#File handling for generating text file 
Txt_file = open(r'Text_output.txt','w+')
opstring = text
Txt_file.write(opstring)
Txt_file.close()

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8 MB)
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8 MB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\thrived\anaconda3\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\thrived\anaconda3\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\thrived\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\thrived\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\thrived\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 100, in resolve
#     r = self.factory.make_requirement_from_install_req(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 301, in make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#     super().__init__(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 480, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 230, in unpack_url
#     file = get_http_url(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 108, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 163, in __call__
#     for chunk in chunks:
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 159, in iter
#     for x in it:
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 64, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\thrived\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='github-releases.githubusercontent.com', port=443): Read timed out.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\thrived\anaconda3\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\thrived\anaconda3\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\thrived\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\thrived\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\thrived\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 100, in resolve
#     r = self.factory.make_requirement_from_install_req(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 301, in make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#     super().__init__(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 480, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 230, in unpack_url
#     file = get_http_url(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 108, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 163, in __call__
#     for chunk in chunks:
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 159, in iter
#     for x in it:
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 64, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\thrived\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\thrived\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='github-releases.githubusercontent.com', port=443): Read timed out.

# %%
nlp = spacy.load('en_core_web_lg')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-ceb8f64bba80> in <module>
# ----> 1 nlp = spacy.load('en_core_web_lg')
#
# ~\anaconda3\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      48     RETURNS (Language): The loaded nlp object.
#      49     """
# ---> 50     return util.load_model(
#      51         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      52     )
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     329     if name in OLD_MODEL_SHORTCUTS:
#     330         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))
# --> 331     raise IOError(Errors.E050.format(name=name))
#     332
#     333
#
# OSError: [E050] Can't find model 'en_core_web_lg'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
doc = nlp(text)
for ent in doc.ents:
    print(ent.text,ent.start_char,ent.label_)
# Out:
# Janu China 0 ORG
# South Asia 33 LOC
# Metropolis 48 GPE
# Central London 82 LOC
# Dubai 118 GPE
# Singapore 163 GPE
# chinese 203 NORP
# about 80,000 275 CARDINAL
# thousands 300 CARDINAL
# each day 325 DATE
# India 514 GPE
# 290 km 525 QUANTITY
# Tamilnadu 542 GPE
# Colombo 570 GPE
# several hectares 620 QUANTITY
# China 694 GPE
# the Indian Ocean 721 LOC
# 10 749 CARDINAL
# Sri Lankan 756 NORP
# China 785 GPE
# the Indian Ocean 843 LOC
# 600 acres 876 QUANTITY
# Sharma Upadhyay 998 PERSON
# China 1014 GPE
# Sri Lanka 1049 GPE
# 1.4 billion dollar 1080 MONEY
# Colombo 1123 GPE
# China 1158 GPE
# first 1345 ORDINAL
# Mahinda Rajapaksa 1415 PERSON
# Sri Lanka 1462 GPE
# Columbus South 1506 LOC
# 2004 1648 DATE
# the next 10 years 1657 DATE
# 2014 1752 DATE
# China 1757 GPE
# Chinese 1827 NORP
# Sri Lanka 1901 GPE
# Chinese 1950 NORP
# 500 1983 CARDINAL
# one 2015 CARDINAL
# Sea 2053 LOC
# Road 2092 ORG

# %%
displacy.serve(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Janu China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  building a gateway to
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Asia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  new
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Metropolis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  about the same size in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  financial analyst in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dubai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  with business friendly atmosphere like
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  which city will be lined with
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  skyscrapers exotic hotels in theme park IL have a population of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 80,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  more commuting
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     each day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that a new job opportunities good money and a good Lifestyle I know it sounds like an enticing plan but wait till you here where this plan is being hacked right in the backyard of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  just
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     290 km
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  away from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tamilnadu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  this is port city
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Colombo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  you know how it being built by reclaiming
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     several hectares
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  of land from the see you know why it being built to give
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and strategic age in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian Ocean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  as I speak
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sri Lankan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  ship sponsored by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  a working overtime to read stand from the bottom of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian Ocean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and put it on a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     600 acres
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  trip to get the city going the question is shouldn't get going at all hello and welcome to gravitaz plus sample
# <mark class="entity" style="background: #aa9cfc; padding: 0.45e
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
